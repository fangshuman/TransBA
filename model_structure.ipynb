# %%
import pretrainedmodels

# %%
vgg16 = pretrainedmodels.vgg16_bn(num_classes=1000, pretrained='imagenet')
for name, _ in vgg16.named_modules():
    print(name)
# Out:
# avgpool
# _features
# _features.0
# _features.1
# _features.2
# _features.3
# _features.4
# _features.5
# _features.6
# _features.7
# _features.8
# _features.9
# _features.10
# _features.11
# _features.12
# _features.13
# _features.14
# _features.15
# _features.16
# _features.17
# _features.18
# _features.19
# _features.20
# _features.21
# _features.22
# _features.23
# _features.24
# _features.25
# _features.26
# _features.27
# _features.28
# _features.29
# _features.30
# _features.31
# _features.32
# _features.33
# _features.34
# _features.35
# _features.36
# _features.37
# _features.38
# _features.39
# _features.40
# _features.41
# _features.42
# _features.43
# linear0
# relu0
# dropout0
# linear1
# relu1
# dropout1
# last_linear

# %%
resnet50 = pretrainedmodels.resnet50(num_classes=1000, pretrained='imagenet')
for name, _ in resnet50.named_modules():
    print(name)
# Out:
# conv1
# bn1
# relu
# maxpool
# layer1
# layer1.0
# layer1.0.conv1
# layer1.0.bn1
# layer1.0.conv2
# layer1.0.bn2
# layer1.0.conv3
# layer1.0.bn3
# layer1.0.relu
# layer1.0.downsample
# layer1.0.downsample.0
# layer1.0.downsample.1
# layer1.1
# layer1.1.conv1
# layer1.1.bn1
# layer1.1.conv2
# layer1.1.bn2
# layer1.1.conv3
# layer1.1.bn3
# layer1.1.relu
# layer1.2
# layer1.2.conv1
# layer1.2.bn1
# layer1.2.conv2
# layer1.2.bn2
# layer1.2.conv3
# layer1.2.bn3
# layer1.2.relu
# layer2
# layer2.0
# layer2.0.conv1
# layer2.0.bn1
# layer2.0.conv2
# layer2.0.bn2
# layer2.0.conv3
# layer2.0.bn3
# layer2.0.relu
# layer2.0.downsample
# layer2.0.downsample.0
# layer2.0.downsample.1
# layer2.1
# layer2.1.conv1
# layer2.1.bn1
# layer2.1.conv2
# layer2.1.bn2
# layer2.1.conv3
# layer2.1.bn3
# layer2.1.relu
# layer2.2
# layer2.2.conv1
# layer2.2.bn1
# layer2.2.conv2
# layer2.2.bn2
# layer2.2.conv3
# layer2.2.bn3
# layer2.2.relu
# layer2.3
# layer2.3.conv1
# layer2.3.bn1
# layer2.3.conv2
# ...

# %%
densenet121 = pretrainedmodels.densenet121(num_classes=1000, pretrained='imagenet')
for name, _ in densenet121.named_modules():
    print(name)
# Out:
# features
# features.conv0
# features.norm0
# features.relu0
# features.pool0
# features.denseblock1
# features.denseblock1.denselayer1
# features.denseblock1.denselayer1.norm1
# features.denseblock1.denselayer1.relu1
# features.denseblock1.denselayer1.conv1
# features.denseblock1.denselayer1.norm2
# features.denseblock1.denselayer1.relu2
# features.denseblock1.denselayer1.conv2
# features.denseblock1.denselayer2
# features.denseblock1.denselayer2.norm1
# features.denseblock1.denselayer2.relu1
# features.denseblock1.denselayer2.conv1
# features.denseblock1.denselayer2.norm2
# features.denseblock1.denselayer2.relu2
# features.denseblock1.denselayer2.conv2
# features.denseblock1.denselayer3
# features.denseblock1.denselayer3.norm1
# features.denseblock1.denselayer3.relu1
# features.denseblock1.denselayer3.conv1
# features.denseblock1.denselayer3.norm2
# features.denseblock1.denselayer3.relu2
# features.denseblock1.denselayer3.conv2
# features.denseblock1.denselayer4
# ...

# %%
inceptionv3 = pretrainedmodels.inceptionv3(num_classes=1000, pretrained='imagenet')
for name, _ in inceptionv3.named_modules():
    print(name)
# Out:
# /home/fangshuman/.local/lib/python3.6/site-packages/torchvision/models/inception.py:77: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   ' due to scipy/scipy#11299), please set init_weights=True.', FutureWarning)
# Conv2d_1a_3x3
# Conv2d_1a_3x3.conv
# Conv2d_1a_3x3.bn
# Conv2d_2a_3x3
# Conv2d_2a_3x3.conv
# Conv2d_2a_3x3.bn
# Conv2d_2b_3x3
# Conv2d_2b_3x3.conv
# Conv2d_2b_3x3.bn
# maxpool1
# Conv2d_3b_1x1
# Conv2d_3b_1x1.conv
# Conv2d_3b_1x1.bn
# Conv2d_4a_3x3
# Conv2d_4a_3x3.conv
# Conv2d_4a_3x3.bn
# maxpool2
# Mixed_5b
# Mixed_5b.branch1x1
# Mixed_5b.branch1x1.conv
# Mixed_5b.branch1x1.bn
# Mixed_5b.branch5x5_1
# Mixed_5b.branch5x5_1.conv
# Mixed_5b.branch5x5_1.bn
# Mixed_5b.branch5x5_2
# Mixed_5b.branch5x5_2.conv
# Mixed_5b.branch5x5_2.bn
# Mixed_5b.branch3x3dbl_1
# ...

# %%
inceptionv4 = pretrainedmodels.inceptionv4(num_classes=1000, pretrained='imagenet')
for name, _ in inceptionv4.named_modules():
    print(name)
# Out:
# features
# features.0
# features.0.conv
# features.0.bn
# features.0.relu
# features.1
# features.1.conv
# features.1.bn
# features.1.relu
# features.2
# features.2.conv
# features.2.bn
# features.2.relu
# features.3
# features.3.maxpool
# features.3.conv
# features.3.conv.conv
# features.3.conv.bn
# features.3.conv.relu
# features.4
# features.4.branch0
# features.4.branch0.0
# features.4.branch0.0.conv
# features.4.branch0.0.bn
# features.4.branch0.0.relu
# features.4.branch0.1
# features.4.branch0.1.conv
# features.4.branch0.1.bn
# features.4.branch0.1.relu
# features.4.branch1
# features.4.branch1.0
# features.4.branch1.0.conv
# features.4.branch1.0.bn
# features.4.branch1.0.relu
# features.4.branch1.1
# features.4.branch1.1.conv
# features.4.branch1.1.bn
# features.4.branch1.1.relu
# features.4.branch1.2
# features.4.branch1.2.conv
# features.4.branch1.2.bn
# features.4.branch1.2.relu
# features.4.branch1.3
# features.4.branch1.3.conv
# features.4.branch1.3.bn
# ...

# %%
incresv2 = pretrainedmodels.inceptionresnetv2(num_classes=1000, pretrained='imagenet')
for name, _ in incresv2.named_modules():
    print(name)
# Out:
# conv2d_1a
# conv2d_1a.conv
# conv2d_1a.bn
# conv2d_1a.relu
# conv2d_2a
# conv2d_2a.conv
# conv2d_2a.bn
# conv2d_2a.relu
# conv2d_2b
# conv2d_2b.conv
# conv2d_2b.bn
# conv2d_2b.relu
# maxpool_3a
# conv2d_3b
# conv2d_3b.conv
# conv2d_3b.bn
# conv2d_3b.relu
# conv2d_4a
# conv2d_4a.conv
# conv2d_4a.bn
# conv2d_4a.relu
# maxpool_5a
# mixed_5b
# mixed_5b.branch0
# mixed_5b.branch0.conv
# mixed_5b.branch0.bn
# mixed_5b.branch0.relu
# mixed_5b.branch1
# mixed_5b.branch1.0
# mixed_5b.branch1.0.conv
# mixed_5b.branch1.0.bn
# mixed_5b.branch1.0.relu
# mixed_5b.branch1.1
# mixed_5b.branch1.1.conv
# mixed_5b.branch1.1.bn
# mixed_5b.branch1.1.relu
# mixed_5b.branch2
# mixed_5b.branch2.0
# mixed_5b.branch2.0.conv
# mixed_5b.branch2.0.bn
# mixed_5b.branch2.0.relu
# mixed_5b.branch2.1
# mixed_5b.branch2.1.conv
# mixed_5b.branch2.1.bn
# mixed_5b.branch2.1.relu
# mixed_5b.branch2.2
# mixed_5b.branch2.2.conv
# mixed_5b.branch2.2.bn
# mixed_5b.branch2.2.relu
# mixed_5b.branch3
# mixed_5b.branch3.0
# ...
